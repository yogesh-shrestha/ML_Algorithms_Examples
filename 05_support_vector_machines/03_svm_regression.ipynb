# %% [markdown]
# ### SVM Regression

# %%
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt

np.random.seed(42)
m = 50
X = 2 * np.random.rand(m, 1)
y = (4 + 3 * X + np.random.randn(m, 1)/2).ravel()

# for prediction
xls = np.linspace(0, 2, 50).reshape(50, 1)


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))

# first model
svm_reg = SVR(kernel='linear',epsilon=1.0)
svm_reg.fit(X, y)
y_pred = svm_reg.predict(xls).ravel()

_ = ax1.scatter(X, y, s = 5)
_ = ax1.plot(xls.ravel(), y_pred, linewidth=2)
_ = ax1.plot(xls.ravel(), y_pred+svm_reg1.epsilon, 'k--' )
_ = ax1.plot(xls.ravel(), y_pred-svm_reg1.epsilon, 'k--' )
_ = ax1.set_title(r'$\epsilon = 1.5$')
_ = ax1.set_xlabel('X')
_ = ax1.set_ylabel('y')

#second model
svm_reg = SVR(kernel='linear',epsilon=0.5)
svm_reg.fit(X, y)
y_pred = svm_reg.predict(xls).ravel()

_ = ax2.scatter(X, y, s = 5)
_ = ax2.plot(xls.ravel(), y_pred, linewidth=2)
_ = ax2.plot(xls.ravel(), y_pred+svm_reg2.epsilon, 'k--' )
_ = ax2.plot(xls.ravel(), y_pred-svm_reg2.epsilon, 'k--' )
_ = ax2.set_title(r'$\epsilon = 0.5$')
_ = ax2.set_xlabel('X')
_ = ax2.set_ylabel('y')
